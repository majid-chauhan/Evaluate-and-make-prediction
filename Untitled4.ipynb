# %% [markdown]
# <a href="https://colab.research.google.com/github/majid-chauhan/Evaluate-and-make-prediction/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error


np.random.seed(42)
hours_studied = np.array([1.1, 1.9, 2.5, 3.2, 3.8, 4.2, 5.1, 5.5, 6.0, 6.8, 7.4, 8.1, 8.9, 9.2]).reshape(-1, 1)
scores = np.array([21, 28, 33, 41, 48, 55, 63, 67, 72, 79, 83, 88, 93, 95])


X_train, X_test, y_train, y_test = train_test_split(
    hours_studied, scores, test_size=0.2, random_state=42
)


model = LinearRegression()
model.fit(X_train, y_train)




y_pred = model.predict(X_test)


mae = mean_absolute_error(y_test, y_pred)
print(f"Mean Absolute Error: {mae:.2f} points")


results = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
print("\nActual vs Predicted Scores:")
print(results)


new_hours = [[4.5]]
predicted_score = model.predict(new_hours)

print(f"\nPredicted score for 4.5 hours: {predicted_score[0]:.2f}")
# Out:
# Mean Absolute Error: 1.72 points
#
# Actual vs Predicted Scores:
#    Actual  Predicted
# 0      79  76.093126
# 1      88  88.182700
# 2      21  23.084997
#
# Predicted score for 4.5 hours: 54.70
